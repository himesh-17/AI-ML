# %%
import json
#Load data

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)

    return data

data = load_data("data.json")

# %%
# cleaning 
def clean_data(data):
    for user in data :
        print(type(user["age"]))
